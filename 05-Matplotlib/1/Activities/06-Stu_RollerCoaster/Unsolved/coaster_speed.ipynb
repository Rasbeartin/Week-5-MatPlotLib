# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
x_axis_data = np.arange(1,130,10)
danger_drop = [9, 8, 90, 85, 80, 70, 70, 65, 55, 60, 70, 65, 50]
rail_gun = [75, 70, 60, 65, 60, 45, 55, 50, 40, 40, 35, 35, 30]
danger_len = len(danger_drop)
rail_len = len(rail_gun)

plt.plot(x_axis_data, danger_drop, 'r+-')
plt.plot(x_axis_data, rail_gun), 'bs-'
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.lines.Line2D at 0x1c1aff3ca90>], 'bs-')
